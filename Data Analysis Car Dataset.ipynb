# %%
import pandas as pd

# %%
car = pd.read_csv(r"C:\Users\kudali vasuki\Favorites\Downloads\cars_data.csv")

# %%
car.head(20)
# Out:
#     3    ?  alfa-romero  gas    std   two  convertible  rwd  front  88.60  \
# 0   3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6
# 1   1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5
# 2   2  164         audi  gas    std  four        sedan  fwd  front   99.8
# 3   2  164         audi  gas    std  four        sedan  4wd  front   99.4
# 4   2    ?         audi  gas    std   two        sedan  fwd  front   99.8
# 5   1  158         audi  gas    std  four        sedan  fwd  front  105.8
# 6   1    ?         audi  gas    std  four        wagon  fwd  front  105.8
# 7   1  158         audi  gas  turbo  four        sedan  fwd  front  105.8
# 8   0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5
# 9   2  192          bmw  gas    std   two        sedan  rwd  front  101.2
# 10  0  192          bmw  gas    std  four        sedan  rwd  front  101.2
# 11  0  188          bmw  gas    std   two        sedan  rwd  front  101.2
# ...

# %%
car.shape
# Out:
# (204, 26)

# %%
#data cleaning
car.isnull()
# Out:
#          3      ?  alfa-romero    gas    std    two  convertible    rwd  \
# 0    False  False        False  False  False  False        False  False
# 1    False  False        False  False  False  False        False  False
# 2    False  False        False  False  False  False        False  False
# 3    False  False        False  False  False  False        False  False
# 4    False  False        False  False  False  False        False  False
# ..     ...    ...          ...    ...    ...    ...          ...    ...
# 199  False  False        False  False  False  False        False  False
# 200  False  False        False  False  False  False        False  False
# 201  False  False        False  False  False  False        False  False
# 202  False  False        False  False  False  False        False  False
# 203  False  False        False  False  False  False        False  False
#
#      front  88.60  ...    130   mpfi   3.47   2.68   9.00    111   5000  \
# ...

# %%
car.isnull().sum()
# Out:
# 3              0
# ?              0
# alfa-romero    0
# gas            0
# std            0
# two            0
# convertible    0
# rwd            0
# front          0
# 88.60          0
# 168.80         0
# 64.10          0
# 48.80          0
# 2548           0
# dohc           0
# four           0
# 130            0
# mpfi           0
# 3.47           0
# 2.68           0
# 9.00           0
# 111            0
# 5000           0
# 21             0
# 27             0
# 13495          0
# dtype: int64

# %%
# to remove null values   which ever column has no null values select that one
car['gas'].fillna(df['gas'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # to remove null values   which ever column has no null values select that one
# ----> 2 car['gas'].fillna(df['gas'].mean())
#
# NameError: name 'df' is not defined

# %%
#value_counts function

# %%
car.head(2)
# Out:
#    3  ?  alfa-romero  gas  std  two  convertible  rwd  front  88.60  ...  130  \
# 0  3  ?  alfa-romero  gas  std  two  convertible  rwd  front   88.6  ...  130
# 1  1  ?  alfa-romero  gas  std  two    hatchback  rwd  front   94.5  ...  152
#
#    mpfi  3.47  2.68 9.00  111  5000  21  27  13495
# 0  mpfi  3.47  2.68  9.0  111  5000  21  27  16500
# 1  mpfi  2.68  3.47  9.0  154  5000  19  26  16500
#
# [2 rows x 26 columns]

# %%
car["gas"].value_counts()
# Out:
# gas       184
# diesel     20
# Name: gas, dtype: int64

# %%
#filter
car[car["mpfi"].isin(['mpfi','2bbl'])]
# Out:
#      3    ?  alfa-romero  gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi  gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi  gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi  gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...  ...    ...   ...          ...  ...    ...    ...
# 198 -1   74        volvo  gas  turbo  four        wagon  rwd  front  104.3
# 199 -1   95        volvo  gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo  gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo  gas    std  four        sedan  rwd  front  109.1
# 203 -1   95        volvo  gas  turbo  four        sedan  rwd  front  109.1
#
#      ...  130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# ...

# %%
#removing unwanted records
car.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
car.rename(columns = {"88.60" : "life"}, inplace = True)

# %%
car.head(2)
# Out:
#    3  ?  alfa-romero  gas  std  two  convertible  rwd  front  life  ...  130  \
# 0  3  ?  alfa-romero  gas  std  two  convertible  rwd  front  88.6  ...  130
# 1  1  ?  alfa-romero  gas  std  two    hatchback  rwd  front  94.5  ...  152
#
#    mpfi  3.47  2.68 9.00  111  5000  21  27  13495
# 0  mpfi  3.47  2.68  9.0  111  5000  21  27  16500
# 1  mpfi  2.68  3.47  9.0  154  5000  19  26  16500
#
# [2 rows x 26 columns]

# %%
car[car["life"] > 90]
# Out:
#      3    ?  alfa-romero     gas    std   two convertible  rwd  front   life  \
# 1    1    ?  alfa-romero     gas    std   two   hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four       sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four       sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two       sedan  fwd  front   99.8
# 5    1  158         audi     gas    std  four       sedan  fwd  front  105.8
# ..  ..  ...          ...     ...    ...   ...         ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four       sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four       sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four       sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four       sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four       sedan  rwd  front  109.1
#
# ...

# %%
car[~(car["life"] > 90)]
# Out:
#      3    ?  alfa-romero  gas  std  two  convertible  rwd  front  life  ...  \
# 0    3    ?  alfa-romero  gas  std  two  convertible  rwd  front  88.6  ...
# 17   2  121    chevrolet  gas  std  two    hatchback  fwd  front  88.4  ...
# 29   2  137        honda  gas  std  two    hatchback  fwd  front  86.6  ...
# 30   2  137        honda  gas  std  two    hatchback  fwd  front  86.6  ...
# 125  3    ?      porsche  gas  std  two      hardtop  rwd   rear  89.5  ...
# 126  3    ?      porsche  gas  std  two      hardtop  rwd   rear  89.5  ...
# 127  3    ?      porsche  gas  std  two  convertible  rwd   rear  89.5  ...
#
#      130  mpfi  3.47  2.68 9.00  111  5000  21  27  13495
# 0    130  mpfi  3.47  2.68  9.0  111  5000  21  27  16500
# 17    61  2bbl  2.91  3.03  9.5   48  5100  47  53   5151
# 29    92  1bbl  2.91  3.41  9.6   58  4800  49  54   6479
# 30    92  1bbl  2.91  3.41  9.2   76  6000  31  38   6855
# 125  194  mpfi  3.74  2.90  9.5  207  5900  17  25  32528
# ...

# %%
car.shape
# Out:
# (204, 26)

# %%
204 - 197
# Out:
# 7

# %%
#there are 7 records which has weight > 90

# %%
#apply function on a column

car.head(2)
# Out:
#    3  ?  alfa-romero  gas  std  two  convertible  rwd  front  life  ...  130  \
# 0  3  ?  alfa-romero  gas  std  two  convertible  rwd  front  88.6  ...  130
# 1  1  ?  alfa-romero  gas  std  two    hatchback  rwd  front  94.5  ...  152
#
#    mpfi  3.47  2.68 9.00  111  5000  21  27  13495
# 0  mpfi  3.47  2.68  9.0  111  5000  21  27  16500
# 1  mpfi  2.68  3.47  9.0  154  5000  19  26  16500
#
# [2 rows x 26 columns]

# %%
#increase all the values of life column by 3
car['life'] = car['life'].apply(lambda x:x+3)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            204 non-null    int64
#  1   ?            204 non-null    object
#  2   alfa-romero  204 non-null    object
#  3   gas          204 non-null    object
#  4   std          204 non-null    object
#  5   two          204 non-null    object
#  6   convertible  204 non-null    object
#  7   rwd          204 non-null    object
#  8   front        204 non-null    object
#  9   life         204 non-null    float64
#  10  168.80       204 non-null    float64
#  11  64.10        204 non-null    float64
#  12  48.80        204 non-null    float64
#  13  2548         204 non-null    int64
#  14  dohc         204 non-null    object
#  15  four         204 non-null    object
#  16  130          204 non-null    int64
#  17  mpfi         204 non-null    object
# ...

# %%
car
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front   life  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   94.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front  100.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front  105.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front  105.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front  105.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  115.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  115.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  115.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  115.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  115.1
#
# ...
