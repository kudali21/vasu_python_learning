# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\kudali vasuki\Favorites\Downloads\country_wise_latest.csv")

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.count()           #no. of no null values present in the column

# null values means missing values.
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# these 2 libraries are used for visualizaton

# %%
sns.heatmap(data.isnull())
plt.show()
#there is no null values.. i.e, complete red.

# %%
# 1. show the no. of confirmed deaths and recovered cases in each region
data.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.groupby("Country/Region")

# %%
data.groupby("Country/Region").sum().head(10)
# Out:
# C:\Users\kudali vasuki\AppData\Local\Temp\ipykernel_8052\2993086434.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Country/Region").sum().head(10)
#                      Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan              36263    1269      25198    9796        106
# Albania                   4880     144       2745    1991        117
# Algeria                  27973    1163      18837    7973        616
# Andorra                    907      52        803      52         10
# Angola                     950      41        242     667         18
# Antigua and Barbuda         86       3         65      18          4
# Argentina               167416    3059      72575   91782       4890
# ...

# %%
# if we want to see only confirmed
# if we want to sort them we use sort_values(ascenind = True/False)
data.groupby("Country/Region")["Confirmed"].sum().sort_values(ascending = False).head(10)
# Out:
# Country/Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Name: Confirmed, dtype: int64

# %%
data.groupby("Country/Region")['Confirmed','Recovered'].sum()
# Out:
# C:\Users\kudali vasuki\AppData\Local\Temp\ipykernel_8052\4180095651.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Country/Region")['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Country/Region
# Afghanistan             36263      25198
# Albania                  4880       2745
# Algeria                 27973      18837
# Andorra                   907        803
# Angola                    950        242
# ...                       ...        ...
# West Bank and Gaza      10621       3752
# Western Sahara             10          8
# Yemen                    1691        833
# Zambia                   4552       2815
# Zimbabwe                 2704        542
#
# [187 rows x 2 columns]

# %%
# 2.remove all records where confirmed cases is less than 10

# %%
data.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.Confirmed < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: Confirmed, Length: 187, dtype: bool

# %%
data[data.Confirmed < 100]
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 5                 Antigua and Barbuda         86       3         65      18
# 17                             Belize         48       2         26      20
# 19                             Bhutan         99       0         86      13
# 49                           Dominica         18       0         18       0
# 59                               Fiji         27       0         18       9
# 68                          Greenland         14       0         13       1
# 69                            Grenada         23       0         23       0
# 75                           Holy See         12       0         12       0
# 94                               Laos         20       0         19       1
# 100                     Liechtenstein         86       1         81       4
# 130                  Papua New Guinea         62       0         11      51
# ...

# %%
data = data[~(data.Confirmed < 100)]

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
# 3. in which region maximum number of confirmed cases are recorded
data.groupby('Country/Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Country/Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Turkey             227019
# Bangladesh         226225
# France             220352
# Germany            207112
# Argentina          167416
# Name: Confirmed, dtype: int64

# %%
# 4.in which region minimum number of deaths are recorded
data.groupby("Country/Region").Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Country/Region
# Mongolia                0
# Eritrea                 0
# Seychelles              0
# Vietnam                 0
# Cambodia                0
# Burundi                 1
# Uganda                  2
# Botswana                2
# Brunei                  3
# Monaco                  4
# Rwanda                  5
# Burma                   6
# Taiwan*                 7
# Comoros                 7
# Barbados                7
# Gambia                  8
# Namibia                 8
# Trinidad and Tobago     8
# Malta                   9
# Iceland                10
# Name: Deaths, dtype: int64

# %%
# 5. how many coonfirmed,deaths & recovered cases are recorded 
#    in india till april 29 2020

# %%
data.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.Country/Region == "India"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data.Country/Region == "India"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
data.rename(columns = {"Country/Region" : "Region"}, inplace = True)
# Out:
# C:\Users\kudali vasuki\AppData\Local\Temp\ipykernel_8052\953132824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns = {"Country/Region" : "Region"}, inplace = True)

# %%
data.head(2)
# Out:
#         Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data
# Out:
#                  Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.Region == 'India'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 181    False
# 182    False
# 184    False
# 185    False
# 186    False
# Name: Region, Length: 171, dtype: bool

# %%
data[data.Region == 'India']
# Out:
#    Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 79  India    1480073   33408     951166  495499      44457         637
#
#     New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 79          33598                2.26                  64.26
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 79                    3.51              1155338         324735
#
#     1 week % increase       WHO Region
# 79              28.11  South-East Asia

# %%
# 6.a) sort the entire data w.r.t no. of confirmed cases in ascending order

# %%
data.head(2)
# Out:
#         Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.sort_values( by = ['Confirmed'])
# Out:
#                   Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 14              Barbados        110       7         94        9          0
# 148           Seychelles        114       0         39       75          0
# 113               Monaco        116       4        104        8          0
# 24                Brunei        141       3        138        0          0
# 170  Trinidad and Tobago        148       8        128       12          1
# ..                   ...        ...     ...        ...      ...        ...
# 154         South Africa     452529    7067     274925   170537       7096
# 138               Russia     816680   13334     602249   201097       5607
# 79                 India    1480073   33408     951166   495499      44457
# 23                Brazil    2442375   87618    1846641   508116      23284
# 173                   US    4290259  148011    1325804  2816444      56336
#
# ...

# %%
# 6.b)sort the entire data w.r.t no. of confirmed cases in descending order

# %%
data.sort_values( by = ['Confirmed'], ascending = False)
# Out:
#                   Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173                   US    4290259  148011    1325804  2816444      56336
# 23                Brazil    2442375   87618    1846641   508116      23284
# 79                 India    1480073   33408     951166   495499      44457
# 138               Russia     816680   13334     602249   201097       5607
# 154         South Africa     452529    7067     274925   170537       7096
# ..                   ...        ...     ...        ...      ...        ...
# 170  Trinidad and Tobago        148       8        128       12          1
# 24                Brunei        141       3        138        0          0
# 113               Monaco        116       4        104        8          0
# 148           Seychelles        114       0         39       75          0
# 14              Barbados        110       7         94        9          0
#
# ...
