# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\kudali vasuki\Favorites\Downloads\police.csv\police.csv")

# %%
data
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# ...

# %%
#1. remove the columns with missing values
data.isnull()
# Out:
#        state  stop_date  stop_time  county_name  driver_gender  driver_race  \
# 0      False      False      False         True          False        False
# 1      False      False      False         True          False        False
# 2      False      False      False         True          False        False
# 3      False      False      False         True          False        False
# 4      False      False      False         True          False        False
# ...      ...        ...        ...          ...            ...          ...
# 91736  False      False      False         True          False        False
# 91737  False      False      False         True          False        False
# 91738  False      False      False         True          False        False
# 91739  False      False      False         True          False        False
# 91740  False      False      False         True          False        False
#
# ...

# %%
data.notnull()
# Out:
#        state  stop_date  stop_time  county_name  driver_gender  driver_race  \
# 0       True       True       True        False           True         True
# 1       True       True       True        False           True         True
# 2       True       True       True        False           True         True
# 3       True       True       True        False           True         True
# 4       True       True       True        False           True         True
# ...      ...        ...        ...          ...            ...          ...
# 91736   True       True       True        False           True         True
# 91737   True       True       True        False           True         True
# 91738   True       True       True        False           True         True
# 91739   True       True       True        False           True         True
# 91740   True       True       True        False           True         True
#
# ...

# %%
data[data.notnull()]
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# ...

# %%
data.notnull().sum()
# Out:
# state                 91741
# stop_date             91741
# stop_time             91741
# county_name               0
# driver_gender         86536
# driver_race           86539
# violation_raw         86539
# violation             86539
# search_conducted      91741
# search_type            3307
# stop_outcome          86539
# is_arrested           86539
# stop_duration         86539
# drugs_related_stop    91741
# district              91741
# dtype: int64

# %%
data.isnull().sum()
# Out:
# state                     0
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5205
# driver_race            5202
# violation_raw          5202
# violation              5202
# search_conducted          0
# search_type           88434
# stop_outcome           5202
# is_arrested            5202
# stop_duration          5202
# drugs_related_stop        0
# district                  0
# dtype: int64

# %%
data.drop( Columns = "driver_gender" inplace = True)

# %%
data
# Out:
#       state   stop_date stop_time                   violation_raw  \
# 0        RI  2005-01-04     12:55  Equipment/Inspection Violation
# 1        RI  2005-01-23     23:15                        Speeding
# 2        RI  2005-02-17     04:15                        Speeding
# 3        RI  2005-02-20     17:15                Call for Service
# 4        RI  2005-02-24     01:20                        Speeding
# ...     ...         ...       ...                             ...
# 91736    RI  2015-12-31     21:21         Other Traffic Violation
# 91737    RI  2015-12-31     21:59                        Speeding
# 91738    RI  2015-12-31     22:04         Other Traffic Violation
# 91739    RI  2015-12-31     22:09  Equipment/Inspection Violation
# 91740    RI  2015-12-31     22:47          Registration Violation
#
#                  violation  search_conducted search_type   stop_outcome  \
# 0                Equipment             False         NaN       Citation
# ...

# %%
# 2. for speeding,men or women stopped more often?

# %%
data.violation == 'Speeding'
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 91736    False
# 91737     True
# 91738    False
# 91739    False
# 91740    False
# Name: violation, Length: 91741, dtype: bool

# %%
data[data.violation == 'Speeding']
# Out:
#       state   stop_date stop_time driver_race violation_raw violation  \
# 1        RI  2005-01-23     23:15       White      Speeding  Speeding
# 2        RI  2005-02-17     04:15       White      Speeding  Speeding
# 4        RI  2005-02-24     01:20       White      Speeding  Speeding
# 5        RI  2005-03-14     10:00       White      Speeding  Speeding
# 6        RI  2005-03-29     21:55       White      Speeding  Speeding
# ...     ...         ...       ...         ...           ...       ...
# 91731    RI  2015-12-31     13:23       White      Speeding  Speeding
# 91732    RI  2015-12-31     18:59       White      Speeding  Speeding
# 91734    RI  2015-12-31     20:20       White      Speeding  Speeding
# 91735    RI  2015-12-31     20:50       White      Speeding  Speeding
# 91737    RI  2015-12-31     21:59       White      Speeding  Speeding
#
#        search_conducted search_type stop_outcome is_arrested stop_duration  \
# ...

# %%
data
# Out:
#       state   stop_date stop_time driver_race                   violation_raw  \
# 0        RI  2005-01-04     12:55       White  Equipment/Inspection Violation
# 1        RI  2005-01-23     23:15       White                        Speeding
# 2        RI  2005-02-17     04:15       White                        Speeding
# 3        RI  2005-02-20     17:15       White                Call for Service
# 4        RI  2005-02-24     01:20       White                        Speeding
# ...     ...         ...       ...         ...                             ...
# 91736    RI  2015-12-31     21:21       Black         Other Traffic Violation
# 91737    RI  2015-12-31     21:59       White                        Speeding
# 91738    RI  2015-12-31     22:04       White         Other Traffic Violation
# 91739    RI  2015-12-31     22:09    Hispanic  Equipment/Inspection Violation
# 91740    RI  2015-12-31     22:47       White          Registration Violation
#
# ...

# %%
data[data.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data[data.violation == 'Speeding'].driver_gender.value_counts()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'driver_gender'

# %%
data = pd.read_csv(r"C:\Users\kudali vasuki\Favorites\Downloads\police.csv\police.csv")

# %%
# 2. filtering and value_counts
data[data.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# M    32777
# F    15646
# Name: driver_gender, dtype: int64

# %%
# 3.  does gender affect who gets searched during a stop?
data.head(5)
# Out:
#   state   stop_date stop_time  county_name driver_gender driver_race  \
# 0    RI  2005-01-04     12:55          NaN             M       White
# 1    RI  2005-01-23     23:15          NaN             M       White
# 2    RI  2005-02-17     04:15          NaN             M       White
# 3    RI  2005-02-20     17:15          NaN             M       White
# 4    RI  2005-02-24     01:20          NaN             F       White
#
#                     violation_raw  violation  search_conducted search_type  \
# 0  Equipment/Inspection Violation  Equipment             False         NaN
# 1                        Speeding   Speeding             False         NaN
# 2                        Speeding   Speeding             False         NaN
# 3                Call for Service      Other             False         NaN
# 4                        Speeding   Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop district
# ...

# %%
#search conducted on which gender is high
data.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     456
# M    2851
# Name: search_conducted, dtype: int64

# %%
#search conducted or not
data.search_conducted.value_counts()
# Out:
# False    88434
# True      3307
# Name: search_conducted, dtype: int64

# %%
#4. mean stop_duration            -- which is a string
data.head(5)
# Out:
#   state   stop_date stop_time  county_name driver_gender driver_race  \
# 0    RI  2005-01-04     12:55          NaN             M       White
# 1    RI  2005-01-23     23:15          NaN             M       White
# 2    RI  2005-02-17     04:15          NaN             M       White
# 3    RI  2005-02-20     17:15          NaN             M       White
# 4    RI  2005-02-24     01:20          NaN             F       White
#
#                     violation_raw  violation  search_conducted search_type  \
# 0  Equipment/Inspection Violation  Equipment             False         NaN
# 1                        Speeding   Speeding             False         NaN
# 2                        Speeding   Speeding             False         NaN
# 3                Call for Service      Other             False         NaN
# 4                        Speeding   Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop district
# ...

# %%
data.stop_duration.value_counts()
# Out:
# 0-15 Min     69579
# 16-30 Min    13740
# 30+ Min       3220
# Name: stop_duration, dtype: int64

# %%
#data typecasting
data['stop_duration'] = data['stop_duration'].map({'0-15 Min' : 7.5, '16-30 Min' : 24, '30+ Min' : 45})

# %%
data
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# ...

# %%
#mean
data['stop_duration'].mean()
# Out:
# 11.515068350685818

# %%
# 5. compare the race distrbutions for each violation (groupby,desc)

# %%
data.head()
# Out:
#   state   stop_date stop_time  county_name driver_gender driver_race  \
# 0    RI  2005-01-04     12:55          NaN             M       White
# 1    RI  2005-01-23     23:15          NaN             M       White
# 2    RI  2005-02-17     04:15          NaN             M       White
# 3    RI  2005-02-20     17:15          NaN             M       White
# 4    RI  2005-02-24     01:20          NaN             F       White
#
#                     violation_raw  violation  search_conducted search_type  \
# 0  Equipment/Inspection Violation  Equipment             False         NaN
# 1                        Speeding   Speeding             False         NaN
# 2                        Speeding   Speeding             False         NaN
# 3                Call for Service      Other             False         NaN
# 4                        Speeding   Speeding             False         NaN
#
#     stop_outcome is_arrested  stop_duration  drugs_related_stop district
# ...

# %%
data.groupby('violation').driver_race.describe()
# Out:
#                      count unique    top   freq
# violation
# Equipment            10922      5  White   6368
# Moving violation     16224      5  White  10527
# Other                 4410      5  White   2844
# Registration/plates   3703      5  White   1980
# Seat belt             2856      5  White   1828
# Speeding             48424      5  White  38325
